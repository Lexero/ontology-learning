# %%
import warnings
warnings.filterwarnings('ignore')

from ontocluster import OntoClusterer
import owlready2 as owl

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating Dataset

# %%
data = pd.read_csv('data.csv')
data.drop(['Timestamp', 'Participant_ID'], 1, inplace = True)
X = pd.get_dummies(data)

from sklearn.decomposition import PCA
pca = PCA(2)
X_dec = pca.fit_transform(X)

# %%
fig, ax = plt.subplots()
ax.scatter(X_dec[:, 0], X_dec[:, 1]);

# %% [markdown]
# # Tests

# %%
model = OntoClusterer('hdbscan')
model.score(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b80f8cfb40cd> in <module>
#       1 model = OntoClusterer('hdbscan')
# ----> 2 model.score(X)
#
# ~\PycharmProjects\OntologyLearning\food-test\ontocluster_test.py in score(self, X)
#     233         model = HDBSCAN()
#     234         start_time = time_ns()
# --> 235         model.fit(X, grid_params = {'min_cluster_size':[2, 3, 4, 5, 6, 7, 8]}, scoring = 'silhouette_score')
#     236         estimation_time = (time_ns() - start_time)//1e6
#     237         scores.at['HDBSCAN', 'Time'] = str(estimation_time)
#
# TypeError: fit() got an unexpected keyword argument 'grid_params'

# %% [markdown]
# ## HDBSCAN

# %%
# %%time
model = OntoClusterer('hdbscan')
onto = model.fit(X, data, grid_params = {'min_cluster_size':[2, 3, 4, 5, 6, 7, 8]}, scoring = 'silhouette_score')
onto.save('hdbscan.owl')
# Out:
# Wall time: 287 ms

# %%
fig, ax = plt.subplots()
ax.scatter(X_dec[:, 0], X_dec[:, 1], c = model.model.labels_);

# %% [markdown]
# ## XMeans

# %%
# %%time
model = OntoClusterer('xmeans')
onto = model.fit(X, data, grid_params = {'kmax':range(0, 100, 10)}, scoring = 'silhouette_score')
onto.save('xmeans.owl')
# Out:
# [[{'kmax': 0}, 0.5879695973201946], [{'kmax': 10}, 0.35105152081765356], [{'kmax': 20}, 0.31464038407380024], [{'kmax': 30}, 0.29313703454508666], [{'kmax': 40}, 0.29995290735337465], [{'kmax': 50}, 0.27882840277583354], [{'kmax': 60}, 0.2878691218371841], [{'kmax': 70}, 0.32297880907446536], [{'kmax': 80}, 0.26766035028514484], [{'kmax': 90}, 0.31873005323287484]]
# 0
# Wall time: 327 ms

# %%
fig, ax = plt.subplots()
ax.scatter(X_dec[:, 0], X_dec[:, 1], c = model.labels);

# %% [markdown]
# ## Affinity Propagation

# %%
# %%time
model = OntoClusterer('affinitypropagation')
onto = model.fit(X, data, grid_params = {'max_iter':range(100, 1000, 100)}, scoring = 'silhouette_score')
onto.save('affinitypropagation.owl')
# Out:
# Wall time: 3.02 s

# %%
fig, ax = plt.subplots()
ax.scatter(X_dec[:, 0], X_dec[:, 1], c = model.model.labels_);

# %% [markdown]
# ## Mean Shift

# %%
# %%time
model = OntoClusterer('meanshift')
onto = model.fit(X, data, grid_params = {'bandwidth':[2, 3, 4, 5, 6], 'max_iter':[300, 600, 900]}, scoring = 'silhouette_score')
onto.save('meanshift.owl')
# Out:
# [[{'bandwidth': 2, 'max_iter': 300}, 0.27788634374492793], [{'bandwidth': 2, 'max_iter': 600}, 0.27788634374492793], [{'bandwidth': 2, 'max_iter': 900}, 0.27788634374492793], [{'bandwidth': 3, 'max_iter': 300}, 0.35987418527721937], [{'bandwidth': 3, 'max_iter': 600}, 0.35987418527721937], [{'bandwidth': 3, 'max_iter': 900}, 0.35987418527721937], [{'bandwidth': 4, 'max_iter': 300}, 0.4044153509978738], [{'bandwidth': 4, 'max_iter': 600}, 0.4044153509978738], [{'bandwidth': 4, 'max_iter': 900}, 0.4044153509978738], [{'bandwidth': 5, 'max_iter': 300}, 0.4346430819518564], [{'bandwidth': 5, 'max_iter': 600}, 0.4346430819518564], [{'bandwidth': 5, 'max_iter': 900}, 0.4346430819518564], [{'bandwidth': 6, 'max_iter': 300}, 0.5082645136129296], [{'bandwidth': 6, 'max_iter': 600}, 0.5082645136129296], [{'bandwidth': 6, 'max_iter': 900}, 0.5082645136129296]]
# 12
# Wall time: 18.8 s

# %%
fig, ax = plt.subplots()
ax.scatter(X_dec[:, 0], X_dec[:, 1], c = model.model.labels_);
